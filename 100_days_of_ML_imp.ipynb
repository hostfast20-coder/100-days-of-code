# %% [markdown]
# <a href="https://colab.research.google.com/github/hostfast20-coder/100-days-of-code/blob/main/100_days_of_ML_imp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
